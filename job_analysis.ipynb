# %% [markdown]
# # Data Analysis Lagou

# %% [markdown]
# ## Get data from lagou

# %%
import time
import pandas
import requests

# %% [markdown]
# #### get target position data

# %%
def getGoalData(data):
    for i in range(15):  # 每页默认15个职位
        info = {
            'positionName': data[i]['positionName'],  # 职位简称
            'companyShortName': data[i]['companyShortName'],  # 平台简称
            'salary': data[i]['salary'],  # 职位薪水
            'createTime': data[i]['createTime'],  # 发布时间
            'companyId': data[i]['companyId'],  # 公司ID
            'companyFullName': data[i]['companyFullName'],  # 公司全称
            'companyLabelList': data[i]['companyLabelList'],  # 公司规模
            'financeStage': data[i]['financeStage'],  # 融资情况
            'positionLables': data[i]['positionLables'],  # 所在行业
            'skillLables': data[i]['skillLables'],
            'education': data[i]['education'],  # 教育背景
            'district': data[i]['district'],  # 公司所在区域
            'workYear': data[i]['workYear']  # 区域详细地
        }
        data[i] = info
    return data

# %% [markdown]
# #### save data as csv file

# %%
def saveData(data):
    table = pandas.DataFrame(data)
    table.to_csv('LaGou1.csv', index=False, mode='a+')

# %% [markdown]
# #### constant definition

# %%
header = {
    'Accept': 'application/json, text/javascript, */*; q=0.01',
    'Referer': 'https://www.lagou.com/jobs/list_%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98/p-city_3?&cl=false&fromSearch=true&labelWords=&suginput=',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36',
    'Host': 'www.lagou.com'}

url1 = 'https://www.lagou.com/jobs/list_%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98?labelWords=&fromSearch=true&suginput='
url = 'https://www.lagou.com/jobs/positionAjax.json?city=%E4%B8%8A%E6%B5%B7&needAddtionalResult=false'
pages = 26

# %% [markdown]
# #### get and save data

# %%
for page in range(1, pages):
    form = {
        'first': 'false',
        'pn': page,
        'kd': '数据挖掘'
    }
    s = requests.Session()  # 建立session
    s.get(url=url1, headers=header, timeout=3)
    cookie = s.cookies  # 获取cookie
    respon = s.post(url=url, headers=header, data=form, cookies=cookie, timeout=3)
    time.sleep(8)
    result = respon.json()
    data = result['content']['positionResult']['result']  # 返回结果在preview中的具体返回值
    try:
        data_goal = getGoalData(data)
        saveData(data_goal)
    except IndexError:
        break

# %% [markdown]
# #### read the csv file and analyse

# %%
from jieba_fast import analyse
import pandas as pd
from pyecharts import Geo
from pyecharts import Pie
from pyecharts import WordCloud
from pyecharts import Funnel
from pyecharts import Bar

# %%
data = pd.read_csv('LaGou1.csv')  # 读取数据
data.head()
# Out:
#       positionName companyShortName   salary           createTime companyId  \
# 0             数据挖掘    The NetCircle  18k-25k  2019-12-09 16:52:22      4670
# 1  数据挖掘工程师（2020校招）            莉莉丝游戏  10k-20k  2019-12-09 15:14:28      1938
# 2             数据挖掘             微创软件  30k-35k  2019-12-09 15:10:53    124652
# 3            算法工程师     NextTao 互道信息  18k-30k  2019-12-09 17:10:55     56474
# 4            算法工程师              趣头条  25k-50k  2019-12-09 17:08:57    202104
#
#   companyFullName                     companyLabelList financeStage  \
# 0    人英网络（上海）有限公司     ['年终分红', '五险一金', '交通补助', '带薪年假']        不需要融资
# 1   上海莉莉丝科技股份有限公司  ['都是萌妹子', '项目奖金', '零食无限量', '牛逼的同事']        不需要融资
# 2    上海微创软件股份有限公司     ['绩效奖金', '带薪年假', '定期体检', '弹性工作']        不需要融资
# 3  互道信息技术（上海）有限公司     ['节日礼物', '技能培训', '年底双薪', '年度旅游']           B轮
# 4    上海基分文化传播有限公司     ['专项奖金', '带薪年假', '弹性工作', '管理规范']         上市公司
#
#                             positionLables                        skillLables  \
# 0  ['社交', 'ETL', 'Java', 'Hadoop', '数据仓库']  ['ETL', 'Java', 'Hadoop', '数据仓库']
# 1                           ['游戏', '数据挖掘']                           ['数据挖掘']
# 2                                       []                           ['数据挖掘']
# 3                     ['机器学习', '推荐', '建模']               ['机器学习', '推荐', '建模']
# 4                       ['电商', '搜索', '推荐']                       ['搜索', '推荐']
#
#   education district workYear
# 0        本科      普陀区     3-5年
# 1        本科      闵行区    应届毕业生
# 2        硕士     浦东新区    5-10年
# 3        本科     浦东新区     1-3年
# 4        本科     浦东新区     3-5年

# %% [markdown]
# #### data cleaning

# %%
# 去除实习岗位和地区为空的岗位
data = data[~data['positionName'].str.contains('intern|实习|产品')]
data = data[~data['district'].isnull()]
data = data[~data['district'].str.contains('district')]
data = data.reset_index(drop=True)
data.head()
# Out:
#       positionName companyShortName   salary           createTime companyId  \
# 0             数据挖掘    The NetCircle  18k-25k  2019-12-09 16:52:22      4670
# 1  数据挖掘工程师（2020校招）            莉莉丝游戏  10k-20k  2019-12-09 15:14:28      1938
# 2             数据挖掘             微创软件  30k-35k  2019-12-09 15:10:53    124652
# 3            算法工程师     NextTao 互道信息  18k-30k  2019-12-09 17:10:55     56474
# 4            算法工程师              趣头条  25k-50k  2019-12-09 17:08:57    202104
#
#   companyFullName                     companyLabelList financeStage  \
# 0    人英网络（上海）有限公司     ['年终分红', '五险一金', '交通补助', '带薪年假']        不需要融资
# 1   上海莉莉丝科技股份有限公司  ['都是萌妹子', '项目奖金', '零食无限量', '牛逼的同事']        不需要融资
# 2    上海微创软件股份有限公司     ['绩效奖金', '带薪年假', '定期体检', '弹性工作']        不需要融资
# 3  互道信息技术（上海）有限公司     ['节日礼物', '技能培训', '年底双薪', '年度旅游']           B轮
# 4    上海基分文化传播有限公司     ['专项奖金', '带薪年假', '弹性工作', '管理规范']         上市公司
#
#                             positionLables                        skillLables  \
# 0  ['社交', 'ETL', 'Java', 'Hadoop', '数据仓库']  ['ETL', 'Java', 'Hadoop', '数据仓库']
# 1                           ['游戏', '数据挖掘']                           ['数据挖掘']
# 2                                       []                           ['数据挖掘']
# 3                     ['机器学习', '推荐', '建模']               ['机器学习', '推荐', '建模']
# 4                       ['电商', '搜索', '推荐']                       ['搜索', '推荐']
#
#   education district workYear
# 0        本科      普陀区     3-5年
# 1        本科      闵行区    应届毕业生
# 2        硕士     浦东新区    5-10年
# 3        本科     浦东新区     1-3年
# 4        本科     浦东新区     3-5年

# %% [markdown]
# #### draw the heat map of job distribution in Shanghai and data mining

# %%
get_district = data.groupby(['district']).count()['positionName'].index.tolist()
count_district = data.groupby(['district']).count()['positionName'].tolist()
get_district = get_district + ['松江区', '奉贤区', '金山区']
count_district = count_district + ['0', '1', '1']
geo = Geo("上海地区’数据挖掘‘职位分布热力图", "data from lagou", title_color="#fff", title_pos="left",
          width=800, height=600,
          background_color='#404a59')
geo.add("职位分布热力图", get_district, count_district, visual_range=[0, 200], type='effectScatter',
        visual_text_color="#fff", symbol_size=15,
        is_visualmap=True, is_roam=True, maptype="上海")  # type有scatter, effectScatter, heatmap三种模式可选，可根据自己的需求选择对应的图表模式
geo.render(path="上海地区’数据挖掘‘职位分布热力图.html")
geo
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="500569f7945f4ae392629dd0b7e4f2ac" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', '上海'], function(echarts) {
#
# var myChart_500569f7945f4ae392629dd0b7e4f2ac = echarts.init(document.getElementById('500569f7945f4ae392629dd0b7e4f2ac'), null, {renderer: 'canvas'});
#
# var option_500569f7945f4ae392629dd0b7e4f2ac = {
#     "title": [
#         {
#             "text": "\u4e0a\u6d77\u5730\u533a\u2019\u6570\u636e\u6316\u6398\u2018\u804c\u4f4d\u5206\u5e03\u70ed\u529b\u56fe",
#             "subtext": "data from lagou",
#             "left": "left",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#fff",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 6173280,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": "{b}: {c}",
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "\u804c\u4f4d\u5206\u5e03\u70ed\u529b\u56fe",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbol": "circle",
#             "symbolSize": 15,
#             "data": [
#                 {
#                     "name": "\u5b9d\u5c71\u533a",
#                     "value": [
#                         121.48,
#                         31.4,
#                         2
#                     ]
#                 },
#                 {
#                     "name": "\u5f90\u6c47\u533a",
#                     "value": [
#                         121.43,
#                         31.18,
#                         19
#                     ]
#                 },
#                 {
#                     "name": "\u666e\u9640\u533a",
#                     "value": [
#                         122.3,
#                         29.95,
#                         6
#                     ]
#                 },
#                 {
#                     "name": "\u6768\u6d66\u533a",
#                     "value": [
#                         121.52,
#                         31.27,
#                         9
#                     ]
#                 },
#                 {
#                     "name": "\u6d66\u4e1c\u65b0\u533a",
#                     "value": [
#                         121.53,
#                         31.22,
#                         48
#                     ]
#                 },
#                 {
#                     "name": "\u8679\u53e3\u533a",
#                     "value": [
#                         121.5,
#                         31.27,
#                         6
#                     ]
#                 },
#                 {
#                     "name": "\u957f\u5b81\u533a",
#                     "value": [
#                         121.42,
#                         31.22,
#                         21
#                     ]
#                 },
#                 {
#                     "name": "\u95f5\u884c\u533a",
#                     "value": [
#                         121.38,
#                         31.12,
#                         17
#                     ]
#                 },
#                 {
#                     "name": "\u95f8\u5317\u533a",
#                     "value": [
#                         121.45,
#                         31.25,
#                         3
#                     ]
#                 },
#                 {
#                     "name": "\u9759\u5b89\u533a",
#                     "value": [
#                         121.45,
#                         31.23,
#                         7
#                     ]
#                 },
#                 {
#                     "name": "\u9ec4\u6d66\u533a",
#                     "value": [
#                         121.48,
#                         31.23,
#                         4
#                     ]
#                 },
#                 {
#                     "name": "\u677e\u6c5f\u533a",
#                     "value": [
#                         121.22,
#                         31.03,
#                         "0"
#                     ]
#                 },
#                 {
#                     "name": "\u5949\u8d24\u533a",
#                     "value": [
#                         121.47,
#                         30.92,
#                         "1"
#                     ]
#                 },
#                 {
#                     "name": "\u91d1\u5c71\u533a",
#                     "value": [
#                         121.33,
#                         30.75,
#                         "1"
#                     ]
#                 }
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u804c\u4f4d\u5206\u5e03\u70ed\u529b\u56fe"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#404a59",
#     "geo": {
#         "map": "\u4e0a\u6d77",
#         "roam": true,
#         "label": {
#             "emphasis": {
#                 "show": true,
#                 "textStyle": {
#                     "color": "#eee"
#                 }
#             }
#         },
#         "itemStyle": {
#             "normal": {
#                 "areaColor": "#323c48",
#                 "borderColor": "#111"
#             },
#             "emphasis": {
#                 "areaColor": "#2a333d"
#             }
#         }
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 0,
#         "max": 200,
#         "text": [
#             "high",
#             "low"
#         ],
#         "textStyle": {
#             "color": "#fff"
#         },
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "dimension": null,
#         "orient": "vertical",
#         "left": "left",
#         "top": "bottom",
#         "showLabel": t

# %% [markdown]
# #### Draw the data mining education pie chart in Shanghai

# %%
get_salary = data.groupby(['salary']).count()['positionName'].index.tolist()
count_salary = data.groupby(['salary']).count()['positionName'].tolist()
get_workYear = data.groupby(['workYear']).count()['positionName'].index.tolist()
count_workYear = data.groupby(['workYear']).count()['positionName'].tolist()
pie_salary = Pie("上海数据挖掘薪酬统计", title_pos='left',width=800, height=620)
pie_salary.add("", get_salary, count_salary, center=[60, 50], radius=[40, 55], label_text_color=None,
        is_label_show=True, legend_orient='vertical',
        legend_pos='left',legend_text_size= 8, legend_top= "8%")
pie_workYear = Pie("上海地区数据挖掘工作年限统计", "data from lagou", title_pos='left', width=900)
pie_workYear.add("工资", get_workYear, count_workYear, center=[50, 50], is_legend_show=True, is_label_show=True)
pie_workYear.render(path="上海地区’数据挖掘‘工作年限饼状图.html")
pie_salary
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="72f8c4464fc54b6294efbf08c7ce7cf7" style="width:800px;height:620px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_72f8c4464fc54b6294efbf08c7ce7cf7 = echarts.init(document.getElementById('72f8c4464fc54b6294efbf08c7ce7cf7'), null, {renderer: 'canvas'});
#
# var option_72f8c4464fc54b6294efbf08c7ce7cf7 = {
#     "title": [
#         {
#             "text": "\u4e0a\u6d77\u6570\u636e\u6316\u6398\u85aa\u916c\u7edf\u8ba1",
#             "subtext": "",
#             "left": "left",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 210008,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "name": "",
#             "data": [
#                 {
#                     "name": "10k-15k",
#                     "value": 4
#                 },
#                 {
#                     "name": "10k-20k",
#                     "value": 8
#                 },
#                 {
#                     "name": "12k-22k",
#                     "value": 1
#                 },
#                 {
#                     "name": "12k-24k",
#                     "value": 1
#                 },
#                 {
#                     "name": "13k-18k",
#                     "value": 1
#                 },
#                 {
#                     "name": "13k-20k",
#                     "value": 1
#                 },
#                 {
#                     "name": "14k-20k",
#                     "value": 1
#                 },
#                 {
#                     "name": "14k-24k",
#                     "value": 1
#                 },
#                 {
#                     "name": "15k-20k",
#                     "value": 2
#                 },
#                 {
#                     "name": "15k-25k",
#                     "value": 11
#                 },
#                 {
#                     "name": "15k-30k",
#                     "value": 9
#                 },
#                 {
#                     "name": "18k-25k",
#                     "value": 1
#                 },
#                 {
#                     "name": "18k-30k",
#                     "value": 4
#                 },
#                 {
#                     "name": "20k-30k",
#                     "value": 6
#                 },
#                 {
#                     "name": "20k-35k",
#                     "value": 2
#                 },
#                 {
#                     "name": "20k-40k",
#                     "value": 18
#                 },
#                 {
#                     "name": "22k-32k",
#                     "value": 1
#                 },
#                 {
#                     "name": "22k-35k",
#                     "value": 1
#                 },
#                 {
#                     "name": "22k-37k",
#                     "value": 1
#                 },
#                 {
#                     "name": "25k-30k",
#                     "value": 1
#                 },
#                 {
#                     "name": "25k-35k",
#                     "value": 2
#                 },
#                 {
#                     "name": "25k-40k",
#                     "value": 4
#                 },
#                 {
#                     "name": "25k-45k",
#                     "value": 2
#                 },
#                 {
#                     "name": "25k-50k",
#                     "value": 19
#                 },
#                 {
#                     "name": "28k-55k",
#                     "value": 2
#                 },
#                 {
#                     "name": "30k-35k",
#                     "value": 1
#                 },
#                 {
#                     "name": "30k-40k",
#                     "value": 4
#                 },
#                 {
#                     "name": "30k-45k",
#                     "value": 1
#                 },
#                 {
#                     "name": "30k-50k",
#                     "value": 2
#                 },
#                 {
#                     "name": "30k-55k",
#                     "value": 1
#                 },
#                 {
#                     "name": "30k-60k",
#                     "value": 11
#                 },
#                 {
#                     "name": "35k-48k",
#                     "value": 1
#                 },
#                 {
#                     "name": "35k-55k",
#                     "value": 2
#                 },
#                 {
#                     "name": "35k-70k",
#                     "value": 3
#                 },
#                 {
#                     "name": "40k-60k",
#                     "value": 4
#                 },
#                 {
#                     "name": "40k-70k",
#                     "value": 1
#                 },
#                 {
#                     "name": "40k-80k",
#                     "value": 3
#                 },
#                 {
#                     "name": "50k-80k",
#                     "value": 1
#                 },
#                 {
#                     "name": "5k-8k",
#                     "value": 1
#                 },
#                 {
#                     "name": "6k-9k",
#                     "value": 1
#                 },
#                 {
#                     "name": "8k-14k",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "55%"
#             ],
#             "center": [
#                 "60%",
#                 "50%"
#             ],
#             "roseType": null,
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "color": null,
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "seriesId": 210008
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "10k-15k",
#                 "10k-20k",
#                 "12k-22k",
#                 "12k-24k",
#                 "13k-18k",
#                 "13k-20k",
#                 "14k-20k",
#                 "14k-24k",
#                 "15k-20k",
#                 "15k-25k",
#                 "15k-30k",
#                 "18k-25k",
#                 "18k-30k",
#                 "20k-30k",
#                 "20k-35k",
#                 "20k-40k",
#                 "22k-32k",
#                 "22k-35k",
#                 "22k-37k",
#                 "25k-30k",
#                 "25k-35k",
#                 "25k-40k",
#                 "25k-45k",
#                 "25k-50k",
#                 "28k-55k",
#                 "30k-35k",
#                 "30k-40k",
#                 "30k-45k",
#                 "30k-50k",
#                 "30k-55k",
#                 "30k-60k",
#                 "35k-48k",
#                 "35k-55k",
#                 "35k-70k",

# %%
pie_workYear
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="1d82f8ee3b92419d9d4d5640b66e6953" style="width:900px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_1d82f8ee3b92419d9d4d5640b66e6953 = echarts.init(document.getElementById('1d82f8ee3b92419d9d4d5640b66e6953'), null, {renderer: 'canvas'});
#
# var option_1d82f8ee3b92419d9d4d5640b66e6953 = {
#     "title": [
#         {
#             "text": "\u4e0a\u6d77\u5730\u533a\u6570\u636e\u6316\u6398\u5de5\u4f5c\u5e74\u9650\u7edf\u8ba1",
#             "subtext": "data from lagou",
#             "left": "left",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 1213064,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u5de5\u8d44",
#             "data": [
#                 {
#                     "name": "1-3\u5e74",
#                     "value": 40
#                 },
#                 {
#                     "name": "3-5\u5e74",
#                     "value": 78
#                 },
#                 {
#                     "name": "5-10\u5e74",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u4e0d\u9650",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u5e94\u5c4a\u6bd5\u4e1a\u751f",
#                     "value": 5
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "roseType": null,
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "seriesId": 1213064
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "1-3\u5e74",
#                 "3-5\u5e74",
#                 "5-10\u5e74",
#                 "\u4e0d\u9650",
#                 "\u5e94\u5c4a\u6bd5\u4e1a\u751f"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_1d82f8ee3b92419d9d4d5640b66e6953.setOption(option_1d82f8ee3b92419d9d4d5640b66e6953);
#
#     });
# </script>

# %% [markdown]
# #### Draw the "data mining" word cloud in Shanghai area

# %%
text = ''
counts = {}
for i in range(len(data['skillLables'])):
    content = data['skillLables'][i].strip()
    text += content
    tags = analyse.extract_tags(text, topK=100, withWeight=False)
    for tag in tags:  # 遍历方法统计词频
        if len(tag) == 1:
            continue
        else:
            counts[tag] = counts.get(tag, 0) + 1
count_skillLables = list(counts.values())
get_skillLables = list(counts.keys())
myWordCloud = WordCloud("绘制词云", width=1000, height=620)
myWordCloud.add("", get_skillLables, count_skillLables, word_size_range=[20, 100])
myWordCloud.render(path="上海地区’职业技能‘词云图.html")
myWordCloud
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/xy/99lj18yj43qc9kttrs_b2v6c0000gn/T/jieba.cache
# Loading model cost 1.624 seconds.
# Prefix dict has been built succesfully.
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="1e2ae81a642a447c8ceb58f77ba9ccc1" style="width:1000px;height:620px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_1e2ae81a642a447c8ceb58f77ba9ccc1 = echarts.init(document.getElementById('1e2ae81a642a447c8ceb58f77ba9ccc1'), null, {renderer: 'canvas'});
#
# var option_1e2ae81a642a447c8ceb58f77ba9ccc1 = {
#     "title": [
#         {
#             "text": "\u7ed8\u5236\u8bcd\u4e91",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3488804,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "ETL",
#                     "value": 142,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(2,150,147)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Java",
#                     "value": 142,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(117,39,79)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Hadoop",
#                     "value": 142,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(133,19,13)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6570\u636e\u4ed3\u5e93",
#                     "value": 142,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(32,125,127)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6570\u636e\u6316\u6398",
#                     "value": 141,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(131,8,153)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5efa\u6a21",
#                     "value": 139,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(35,85,116)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u673a\u5668",
#                     "value": 139,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(23,35,22)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b66\u4e60",
#                     "value": 139,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(147,61,115)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u63a8\u8350",
#                     "value": 139,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(21,25,133)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u641c\u7d22",
#                     "value": 138,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(142,26,66)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4eba\u5de5\u667a\u80fd",
#                     "value": 137,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(22,158,18)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7b97\u6cd5",
#                     "value": 137,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(17,128,35)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u56fe\u50cf\u5904\u7406",
#                     "value": 136,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(53,44,127)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "BI",
#                     "value": 132,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(23,79,13)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6570\u636e\u5206\u6790",
#                     "value": 132,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(111,158,19)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u98ce\u63a7",
#                     "value": 129,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(154,3,41)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7b56\u7565",
#                     "value": 129,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(41,110,56)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5206\u6790\u5e08",
#                     "value": 129,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(110,158,65)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8bbe\u8ba1",
#                     "value": 129,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(9,73,150)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "NLP",
#                     "value": 128,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(77,107,34)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6df1\u5ea6",
#                     "va

# %%
text = ''
counts = {}
for i in range(len(data['positionLables'])):
    content = data['positionLables'][i].strip()
    text += content
    tags = analyse.extract_tags(text, topK=100, withWeight=False)
    for tag in tags:  # 遍历方法统计词频
        if len(tag) == 1:
            continue
        else:
            counts[tag] = counts.get(tag, 0) + 1
count_skillLables = list(counts.values())
get_skillLables = list(counts.keys())
myWordCloud = WordCloud("数据挖掘标签", width=1000, height=620)
myWordCloud.add("", get_skillLables, count_skillLables, word_size_range=[20, 100])
myWordCloud.render(path="上海地区’职位技能‘词云图.html")
myWordCloud
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="8255f54a7dc04aab8e00ef67ce0700d2" style="width:1000px;height:620px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_8255f54a7dc04aab8e00ef67ce0700d2 = echarts.init(document.getElementById('8255f54a7dc04aab8e00ef67ce0700d2'), null, {renderer: 'canvas'});
#
# var option_8255f54a7dc04aab8e00ef67ce0700d2 = {
#     "title": [
#         {
#             "text": "\u6570\u636e\u6316\u6398\u6807\u7b7e",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 400146,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "ETL",
#                     "value": 142,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(75,50,67)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Java",
#                     "value": 142,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(110,85,43)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Hadoop",
#                     "value": 142,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(155,17,125)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6570\u636e\u4ed3\u5e93",
#                     "value": 142,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(102,127,59)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u793e\u4ea4",
#                     "value": 142,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(119,77,95)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6570\u636e\u6316\u6398",
#                     "value": 141,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(23,55,87)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6e38\u620f",
#                     "value": 141,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(107,46,75)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5efa\u6a21",
#                     "value": 139,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,86,97)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u673a\u5668",
#                     "value": 139,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(7,20,141)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b66\u4e60",
#                     "value": 139,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(96,29,1)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u63a8\u8350",
#                     "value": 139,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(99,14,71)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7535\u5546",
#                     "value": 138,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(58,7,116)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u641c\u7d22",
#                     "value": 138,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(59,158,57)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4eba\u5de5\u667a\u80fd",
#                     "value": 137,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(91,107,159)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7b97\u6cd5",
#                     "value": 137,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(139,118,146)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u56fe\u50cf\u5904\u7406",
#                     "value": 136,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(41,102,142)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e7f\u544a",
#                     "value": 136,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(147,120,8)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8425\u9500",
#                     "value": 136,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(71,51,42)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e92\u8054\u7f51",
#                     "value": 136,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(134,80,63)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u79fb\u52a8",
#                     "value": 136,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(54,25,40)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "BI",

# %%
get_financeStage = data.groupby(['financeStage']).count()['positionName'].index.tolist()
count_financeStage = data.groupby(['financeStage']).count()['positionName'].tolist()
funnel = Funnel("融资阶段漏斗图", width=1000, height=620)
funnel.add("商品", get_financeStage, count_financeStage, is_label_show=True, label_pos="inside", label_text_color="#fff")
funnel.render()
funnel
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="e3d16a0e46a2442aa98b27c314d9f4ef" style="width:1000px;height:620px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_e3d16a0e46a2442aa98b27c314d9f4ef = echarts.init(document.getElementById('e3d16a0e46a2442aa98b27c314d9f4ef'), null, {renderer: 'canvas'});
#
# var option_e3d16a0e46a2442aa98b27c314d9f4ef = {
#     "title": [
#         {
#             "text": "\u878d\u8d44\u9636\u6bb5\u6f0f\u6597\u56fe",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 6356950,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "A\u8f6e",
#                     "value": 16
#                 },
#                 {
#                     "name": "B\u8f6e",
#                     "value": 15
#                 },
#                 {
#                     "name": "C\u8f6e",
#                     "value": 14
#                 },
#                 {
#                     "name": "D\u8f6e\u53ca\u4ee5\u4e0a",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u4e0a\u5e02\u516c\u53f8",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u4e0d\u9700\u8981\u878d\u8d44",
#                     "value": 29
#                 },
#                 {
#                     "name": "\u5929\u4f7f\u8f6e",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u672a\u878d\u8d44",
#                     "value": 10
#                 }
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "inside",
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u672a\u878d\u8d44",
#                 "\u4e0d\u9700\u8981\u878d\u8d44",
#                 "\u5929\u4f7f\u8f6e",
#                 "D\u8f6e\u53ca\u4ee5\u4e0a",
#                 "C\u8f6e",
#                 "\u4e0a\u5e02\u516c\u53f8",
#                 "A\u8f6e",
#                 "B\u8f6e"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_e3d16a0e46a2442aa98b27c314d9f4ef.setOption(option_e3d16a0e46a2442aa98b27c314d9f4ef);
#
#     });
# </script>

# %%
get_education = data.groupby(['education']).count()['positionName'].index.tolist()
count_education = data.groupby(['education']).count()['positionName'].tolist()
bar = Bar("数据挖掘学历分布", "来自拉勾")
bar.add("服装", get_education, count_education)
bar.render()
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="2227965490934dd1a4fa417b46a2e912" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_2227965490934dd1a4fa417b46a2e912 = echarts.init(document.getElementById('2227965490934dd1a4fa417b46a2e912'), null, {renderer: 'canvas'});
#
# var option_2227965490934dd1a4fa417b46a2e912 = {
#     "title": [
#         {
#             "text": "\u6570\u636e\u6316\u6398\u5b66\u5386\u5206\u5e03",
#             "subtext": "\u6765\u81ea\u62c9\u52fe",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3746642,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u670d\u88c5",
#             "data": [
#                 5,
#                 3,
#                 102,
#                 32
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 3746642
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u670d\u88c5"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "type": "category",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": null,
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 }
#             },
#             "data": [
#                 "\u4e0d\u9650",
#                 "\u5927\u4e13",
#                 "\u672c\u79d1",
#                 "\u7855\u58eb"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_2227965490934dd1a4fa417b46a2e912.setOption(option_2227965490934dd1a4fa417b46a2e912);
#
#     });
# </script>
